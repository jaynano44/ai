# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.text_cell_render.rendered_html{font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.text_cell_render.rendered_html{font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %%
import numpy as np
from tensorflow.keras.models import Sequential  # 모델 객체 생성
from tensorflow.keras.layers import Input, Dense  # 모델 Layer 쌓을 때 필요
import matplotlib.pyplot as plt

# %%
# 1. data set
x_data = np.array([[0,0],
                  [0,1],
                  [1,0],
                  [1,1]])
y_data = np.array([[0],
                  [1],
                  [1],
                  [0]])

# 2. 모델 구성 (layer 층을 X2 => 10 => 20 => 10 => y1 일 때)
model = Sequential()
# model.add(Input(shape=2))
model.add(Dense(units=10,        # 출력갯수
               input_dim=2,      #input_shape =(2,) # 입력 갯수
               activation='relu')) # 활성화 함수
model.add(Dense(units=20, activation='relu')) # 은닉층에서는 input_shape는 X
model.add(Dense(10,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))
print(model.summary())

# 3. 모델 학습과정 설정
    # loss : mae(회귀분석), binary_crossentropy(이진분류 =로지스틱회귀분석), 
          # categorical_crossentropy(다중분류 - 원핫인코딩을 한 경우)
          # sparse_categorical_crossentropy (다중분류 - 원핫인코딩을 안한 경우)
model.compile(loss = 'binary_crossentropy',   # 손실함수(loss function)   
             optimizer='adam',
             metrics=['binary_accuracy'])     # 2진분류
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 10)                30
#
#  dense_9 (Dense)             (None, 20)                220
#
#  dense_10 (Dense)            (None, 10)                210
#
#  dense_11 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 4. 학습 - 
hist = model.fit(x_data,y_data,epochs=300,verbose=2)
# Out:
# Epoch 1/300
# 1/1 - 0s - loss: 0.7031 - binary_accuracy: 0.7500 - 440ms/epoch - 440ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 0.7024 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 0.7014 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 0.7004 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 0.6995 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 0.6985 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 0.6975 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 0.6965 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 0.6955 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 0.6945 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 0.6935 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 0.6926 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 0.6916 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 0.6906 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 0.6896 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 0.6885 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 0.6875 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 0.6865 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 0.6855 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 0.6847 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 0.6838 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 0.6830 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 0.6821 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 0.6813 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 0.6805 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 0.6797 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 0.6788 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 0.6780 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 0.6771 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 0.6762 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 0.6752 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 0.6739 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 0.6726 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 0.6713 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 0.6700 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 0.6686 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 0.6671 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 0.6656 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 0.6640 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 0.6625 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 0.6610 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 0.6595 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 0.6580 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 0.6563 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 0.6547 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 0.6531 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 0.6515 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 0.6498 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 0.6481 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 0.6463 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 0.6452 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 0.6440 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 0.6429 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 0.6416 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 0.6404 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 0.6390 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 0.6377 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 0.6363 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 0.6349 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 0.6335 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 0.6320 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 0.6305 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 0.6290 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 0.6274 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 0.6257 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 0.6242 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 0.6225 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 0.6208 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 0.6191 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 0.6174 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 0.6156 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 0.6139 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 0.6121 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 0.6104 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 0.6088 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 0.6071 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 0.6053 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 0.6034 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 0.6015 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 0.5996 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 0.5978 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 0.5959 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 0.5938 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 0.5918 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 0.5898 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 0.5877 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 0.5856 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 0.5834 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 0.5812 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 0.5791 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 0.5769 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 0.5747 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 0.5723 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 0.5700 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 0.5678 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 0.5654 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 0.5629 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 0.5607 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 0.5582 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 0.5557 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 0.5532 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 0.5509 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 0.5484 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 0.5458 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 0.5432 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 0.5406 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 0.5383 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 0.5353 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 0.5325 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 0.5300 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 0.5274 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 0.5245 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 0.5218 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 0.5190 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.5163 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.5135 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.5106 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 0.5077 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 0.5048 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.5019 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.4989 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.4960 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.4929 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.4899 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.4869 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.4838 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.4807 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.4777 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.4745 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.4715 - binary_accuracy: 1.0000 - 995us/epoch - 995us/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.4684 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.4653 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.4622 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.4589 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.4559 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.4528 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.4496 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.4463 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.4431 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.4399 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.4366 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.4333 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.4299 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.4266 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.4232 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.4200 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.4165 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.4132 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.4099 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.4065 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.4031 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.3997 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.3963 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.3931 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.3896 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.3861 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.3829 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.3795 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.3760 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.3726 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.3692 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.3656 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.3623 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.3589 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.3557 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.3521 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.3488 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.3456 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.3423 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.3390 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.3356 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.3321 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.3289 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.3254 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.3221 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.3189 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.3156 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.3124 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.3091 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.3058 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.3025 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.2992 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.2963 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.2932 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.2899 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.2867 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.2836 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.2805 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.2774 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.2742 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.2711 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.2681 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.2651 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.2621 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.2591 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.2561 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.2533 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.2503 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.2472 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.2445 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.2416 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.2389 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.2361 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.2332 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.2305 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.2277 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.2251 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.2224 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.2196 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.2171 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.2144 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.2118 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.2093 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.2068 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.2044 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.2018 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.1994 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.1970 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.1945 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.1921 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.1897 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.1874 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.1851 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.1828 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.1806 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.1783 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.1761 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.1740 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.1719 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.1698 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.1676 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.1655 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.1635 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.1615 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.1594 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.1574 - binary_accuracy: 1.0000 - 994us/epoch - 994us/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.1555 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.1535 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.1516 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.1497 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.1479 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.1460 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.1442 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.1424 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.1407 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.1390 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.1372 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.1356 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.1339 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.1322 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.1306 - binary_accuracy: 1.0000 - 994us/epoch - 994us/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.1290 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.1273 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.1258 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.1242 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.1228 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.1212 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.1198 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.1183 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.1168 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.1154 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.1141 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.1127 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.1113 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.1099 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.1086 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.1073 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.1060 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.1047 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.1034 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.1022 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.1009 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.0997 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.0985 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.0974 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.0962 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.0951 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.0940 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.0928 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.0917 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.0907 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.0896 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.0885 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.0875 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.0865 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.0855 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.0845 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.0835 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.0826 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.0816 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.0806 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.0797 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.0788 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.0779 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.0770 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.0762 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.0753 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.0744 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.0736 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.0728 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step

# %%
# 5. 학습과정 살펴보기
hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy'])

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'],'b',label='loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax
acc_ax.plot(hist.history['binary_accuracy'],'r',label='binary_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('binary_accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='center left')
plt.show()

# %%
# 모델 평가하기
score = model.evaluate(x_data,y_data)  # loss & metrics(binary accuracy)
print('loss :',score)
print('accuracy :',score[1])
# Out:
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0720 - binary_accuracy: 1.0000
# loss : [0.07197337597608566, 1.0]
# accuracy : 1.0

# %%
# 예측하기
model.predict(np.array([[0,1]]))
# Out:
# 1/1 [==============================] - 0s 94ms/step
# array([[0.9679082]], dtype=float32)
