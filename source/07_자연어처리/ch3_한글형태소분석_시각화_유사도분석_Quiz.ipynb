# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.text_cell_render.rendered_html{font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.text_cell_render.rendered_html{font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# # ※Quiz :  경주 여행과 전주 여행에 대해 최빈 단어시각화와 유사도분석
#
# - (1) naver open API 를 이용해서 네이버지식인 "전주여행","경주여행"를 각각 500건씩 검색 백업(naver.csv)
#     * replace(), re.sum()이용
#     * 백업 파일 결과 : query,no,title,link,description,total_text(title+' '+description)
# - (2) 품사태깅 백업(naver_pos.csv)
#     * query,no, token,pos
# - (3) 명사만 추출 백업(naver_pos_nouns.csv)
#     * query, token, pos
# - (4) 빈도분석 백업(naver_pos_nouns_count.csv)
#     * token, 경주빈도, 전주빈도, 빈도합
# - (5) 빈도 시각화(워드클라우드, Text.plot)
#     * 워드클라우드 이미지 저장
# - (6) 단어간 유사도 분석 ( Word2Vec,연관분석)
#
# # 1. naver open API 를 활용
# - query,no,title,link,description,total_text(title+' '+description)

# %%
# .env 가져오기(방법1) - 추천(주피터노트북)
from dotenv import load_dotenv
import os
load_dotenv()
# print(os.getenv('CLIENT_ID'))
# print(os.getenv('CLIENT_SECRET'))
# Out:
# True

# %%
# .env 가져오기(방법2) - VS-code에서 추천
from decouple import config
# print(config('CLIENT_ID'))
# print(config('CLIENT_SECRET'))

# %%
# 방법1
import requests
import pandas as pd
import json # response 택스트를 json스타일의 딕셔너리로 
import re  # 정규표현식
from html import unescape # description에 &lt; &nbps 등의 특수문자를 <(문자)>로 변경

client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')
query = '경주 여행'
start = 1
headers = {
    'X-Naver-Client-Id':client_id,
    'X-Naver-Client-Secret':client_secret
}
# url = f"https://openapi.naver.com/v1/search/kin?query={query}&display=100 & start={start}"
# response = requests.get(url,headers=headers)
url = "https://openapi.naver.com/v1/search/kin"
params = {'query':query,'display':100,'start':start}
response = requests.get(url,params=params,headers=headers)
# print(response.text[:500])
# items = json.loads(response.text)['items']
items = response.json()['items']
print(len(items))
# Out:
# 100

# %%
# title,link,description 추출(b태그삭제,특수문자조정(&gt;-> >),정규표현식을 이용한 한글 추출)
item = items[97]
title = item.get('title').replace('<b>',' ').replace('</b>',' ')
link = item['link']
description = item.get('description').replace('<b>',' ').replace('</b>',' ')
# html 특수문자 처리
description = unescape(description)
# 정규표현식 : 알파벳, 숫자, 한글만 남기고 나머지는 제거
description = re.sub(r'[^a-zA-Z0-9가-힣]',' ',description)
description = re.sub('\s+',' ',description)
print(title,link,description)
# Out:
#  경주 여행 지 추천 https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=261370795&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8  2 부산을 벗어난 경주 여행 지 알려주세요 3 당일치기로 경주 여행 코스 밑에 자세하게 권역별로 여행코스를 소개했습니다 경주여행 이 처음이라면 대릉원 첨성대 참고로 쭈니아빠 블로그를 방문하시면 경주여행

# %%
def get_search_element_return(query,start):
    headers = {
        'X-Naver-Client-Id':client_id,
        'X-Naver-Client-Secret':client_secret
    }
    # url = f"https://openapi.naver.com/v1/search/kin?query={query}&display=100 & start={start}"
    # response = requests.get(url,headers=headers)
    url = "https://openapi.naver.com/v1/search/kin"
    params = {'query':query,'display':100,'start':start}
    response = requests.get(url,params=params,headers=headers)
    # print(response.text[:500])
    # items = json.loads(response.text)['items']
    items = response.json()['items']
    result = [] # 검색할 정보를 append할 리스트
    for i, item in enumerate(items):
        title = item.get('title').replace('<b>','').replace('</b>','')
        link = item.get('link')
        description = item.get('description').replace('<b>',' ').replace('</b>',' ')
        # 특수문자
        description = unescape(description)
        # 영문자, 숫자, 한글을 제외한 문자 제거
        description = re.sub(r'[^a-zA-Z0-9가-힣]',' ',description)
        description = re.sub('\s+',' ',description)
        result.append({
            'query':query,
            'no':(start-1)*100 + i + 1,
            'title':title,
            'link':link,
            'description':description,
            'total_text': title + ' ' + description  
        })
    return result

# %%
import time
result_total = [] # 모든 검색 결과
queries = ['전주 여행','경주 여행']
max_start = 5
for query in queries:
    for start in range(1,max_start+1):
        print(start,query,'읽는중')
        result_total.extend(get_search_element_return(query,start))
        time.sleep(0.5)
df = pd.DataFrame(result_total)
df.to_csv('data/naver.csv',index=False)
# Out:
# 1 전주 여행 읽는중
# 2 전주 여행 읽는중
# 3 전주 여행 읽는중
# 4 전주 여행 읽는중
# 5 전주 여행 읽는중
# 1 경주 여행 읽는중
# 2 경주 여행 읽는중
# 3 경주 여행 읽는중
# 4 경주 여행 읽는중
# 5 경주 여행 읽는중

# %% [markdown]
# # 2. 품사태깅
#
# - query, no, token, pos

# %%
import pandas as pd
df = pd.read_csv('data/naver.csv')
df.tail(2)
# Out:
#      query   no             title  \
# 998  경주 여행  499  경주 여행가면 볼거 많겠죠??
# 999  경주 여행  500            경주여행!!
#
#                                                   link  \
# 998  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 999  https://kin.naver.com/qna/detail.naver?d1id=9&...
#
#                                            description  \
# 998  중학생인데 경주 여행 가볼려고 하는데 볼거 많겠죠 경주 가볼만한곳 입니다 불국사 첨...
# 999   경주 여행 을 가려고 하는데 혹시 경주에 폴라로이드 카메라 대여 할 수 있는곳이나...
#
#                                             total_text
# 998  경주 여행가면 볼거 많겠죠?? 중학생인데 경주 여행 가볼려고 하는데 볼거 많겠죠 경...
# 999  경주여행!!  경주 여행 을 가려고 하는데 혹시 경주에 폴라로이드 카메라 대여 할 ...

# %%
df_list = df[['query','no','total_text']].values.tolist()
df_list[::250]
# Out:
# [['전주 여행',
#   1,
#   '25년10월5,6,7일 전주여행  전주여행 가볼만한 곳 추천부탁드립니다 25년 10월 초 전주여행 아이들과 함께 가기 좋은 시점이에요 추석에는 문 연 곳이 적을 수 있지만 전주 한옥마을이나 전주비빔밥 맛집은 추천해용 차는 밀릴 가능성이 높으니 미리 출발하는 '],
#  ['전주 여행',
#   251,
#   '[추천해주세요] 전주 당일치기 여행  추천해주세요 전주 당일치기 여행 전주여행 전주맛집 국내여행 전주달봉이 달봉티비 전주여행 코스 전주가볼만한곳 여수여행 여수가볼만한곳 제주도여행 제주도가볼만한곳 여행 전문 인플루언서 전주달봉이입니다 '],
#  ['경주 여행',
#   1,
#   'APEC 기간 경주여행 APEC 기간 경주여행 어떻게 생각하시나요 APEC 기간에 경주여행 은 좋은 방법이에요 역사와 문화가 가득한 도시에서 특별한 경험을 할 수 있을 거에요 즐거운 여행 되세요 '],
#  ['경주 여행',
#   251,
#   '경주 여행 코스 어디가★ 가족들이랑 경주여행 을 가려고 하는데 경주 여행 코스를 어떻게 해야할지 모르겟네요 경주 여행 코스 어디가 좋을까요 사실 중학교때 가보고 안가봤어요 경주 여행 코스 가장 핫플레이스만 가보고 싶어요 혹시 경주 여행 코스 다들 ']]

# %%
from mecab import MeCab
analyzer = MeCab()
stopwords = {'전주','경주','여행'}
postagged_list = [] # query, no, token, pos 딕셔너리list

for i, row in enumerate(df_list):
    query = row[0]
    no    = row[1]
    text  = row[2]
    tagged_text = analyzer.pos(text)
#     if i%250==0:
#         print("{}의 {}번째 품사태깅결과 : {}개".format(query,no,len(tagged_text)))
        #print(tagged_text[5:15])
    for token, pos in tagged_text:
        #if token not in stopwords and pos in select_pos : # 불용어 제외한 명사
        if token not in stopwords: # 불용어 제외 ,한글자 이상만 append
            postagged_list.append({
                'query':query,
                'no':no,
                'token':token,
                'pos':pos
            })
df_postagged = pd.DataFrame(postagged_list)  
df_postagged.to_csv('data/naver_pos.csv',index=False,encoding='cp949')

# %%
df_postagged.shape
# Out:
# (54121, 4)

# %% [markdown]
# # 3. 명사만 추출

# %%
import pandas as pd
df_postagged = pd.read_csv('data/naver_pos.csv',encoding='cp949')
df_postagged.head(1)
# Out:
#    query  no token pos
# 0  전주 여행   1    25  SN

# %%
select_pos = ['NNG','NNP'] # mecab의 명사 pos tag
df_nouns = df_postagged[df_postagged['pos'].isin(select_pos)]
df_nouns.to_csv('data/naver_pos_nouns.csv',index=False,encoding='cp949')

# %% [markdown]
# # 4. 빈도분석
#
# - token 경주빈도  전주빈도  빈도합

# %%
df_nouns = pd.read_csv('data/naver_pos_nouns.csv',encoding='cp949')
df_nouns.head()
# Out:
#    query  no token  pos
# 0  전주 여행   1     곳  NNG
# 1  전주 여행   1    추천  NNG
# 2  전주 여행   1    부탁  NNG
# 3  전주 여행   1    아이  NNG
# 4  전주 여행   1    시점  NNG

# %%
df_nouns.groupby(['query','token'],as_index=False)['pos'].count()
# Out:
#      query token  pos
# 0    경주 여행    가격    5
# 1    경주 여행    가능   30
# 2    경주 여행  가보세요   10
# 3    경주 여행   가본적    5
# 4    경주 여행    가시    5
# ..     ...   ...  ...
# 995  전주 여행    효율    5
# 996  전주 여행     후    5
# 997  전주 여행    휴가    5
# 998  전주 여행    휴무    5
# 999  전주 여행    흐노    5
#
# [1000 rows x 3 columns]

# %%
df_token_grp = df_nouns.groupby('query')['token'].value_counts()
df_token_grp = df_token_grp.reset_index(name='token_count')

# %%
df_token_grp.head()
# Out:
#    query token  token_count
# 0  경주 여행    코스          447
# 1  경주 여행    추천          424
# 2  경주 여행    계획          151
# 3  경주 여행     곳          134
# 4  경주 여행    맛집          133

# %%
df_gj = df_token_grp.loc[df_token_grp['query']=='경주 여행',['token','token_count']]
df_jj = df_token_grp.loc[df_token_grp['query']=='전주 여행',['token','token_count']]
df_gj.shape,df_jj.shape
# Out:
# ((535, 2), (465, 2))

# %%
df_gj.head()
# Out:
#   token  token_count
# 0    코스          447
# 1    추천          424
# 2    계획          151
# 3     곳          134
# 4    맛집          133

# %%
df_jj.head()
# Out:
#     token  token_count
# 535    코스          459
# 536     곳          433
# 537     봉          330
# 538    맛집          322
# 539    여수          315

# %%
#df_gj(경주 명사 출현 횟수), df_jj(전주 명사 출현 횟수) 병합
import numpy as np
df_mrg = pd.merge(df_gj,df_jj,on='token', how='outer')
df_mrg.columns = ['token','경주빈도','전주빈도']
df_mrg.fillna(0,inplace=True)
df_mrg['경주빈도'] = df_mrg['경주빈도'].astype('int')
df_mrg['전주빈도'] = df_mrg['전주빈도'].astype(np.int32)
df_mrg.head()
# Out:
#   token  경주빈도  전주빈도
# 0    코스   447   459
# 1    추천   424   289
# 2    계획   151    64
# 3     곳   134   433
# 4    맛집   133   322

# %%
df_mrg['빈도합'] = df_mrg['경주빈도']+df_mrg['전주빈도']
df_mrg['경주비율'] = df_mrg['경주빈도']/df_mrg['빈도합']
df_mrg['전주비율'] = df_mrg['전주빈도']/df_mrg['빈도합']
df_mrg['경주비율'] = df_mrg['경주비율'].apply(lambda x : "{:.2%}".format(x))
df_mrg['전주비율'] = df_mrg['전주비율'].apply(lambda x : "{:.2%}".format(x))
df_mrg.to_csv('data/naver_pos_nouns_count.csv',index=False,encoding='cp949')

# %% [markdown]
# # 5. 빈도 시각화(워드클라우드, Text)
#
# - 전주 여행 워드 클라우드/ 경주 여행 워드클라우드

# %%
df_nouns = pd.read_csv('data/naver_pos_nouns.csv',encoding='cp949')
df_nouns.loc[::3000]
# Out:
#        query   no token  pos
# 0      전주 여행    1     곳  NNG
# 3000   전주 여행  163    예상  NNG
# 6000   전주 여행  327  대중교통  NNG
# 9000   전주 여행  490    전문  NNG
# 12000  경주 여행  185     인  NNG
# 15000  경주 여행  377    인원  NNG

# %%
df_gj_noun_list = df_nouns.loc[df_nouns['query']=='경주 여행','token'].to_list()
df_jj_noun_list = df_nouns.loc[df_nouns['query']=='전주 여행','token'].to_list()
gj_text = ' '.join(df_gj_noun_list)
jj_text = ' '.join(df_jj_noun_list)
# Out:
# '곳 추천 부탁 아이 시점 추석 문 연 곳 한옥마을 전주비빔밥 맛집 추천 해용 차 가능 출발 주요 관광지 도보 이동 계획 주역 한옥마을 도보 정도 정도 대부분 택시 버스 이용 택시 정도 도착 요금 정도 부담 아이 중순 아이 당일치기 처음 야 식당 중순 아이 당일치기 아이 부모 커플 코스 포함 문화 체험 활동 커플 문화 체험 활동 포함 한복 대여 전통 
한옥마을 카페 투어 코스 스로 여자 질문 다음 일정 추천 한옥마을 전통 한옥 건물 전통 문화 경험 향교 조선 시대 교육 기관 향교 남부 시장 의 휴가 코스 추천 위 일정 참고 제시 일정 조정 음식점 웨이팅 시간 방문 시간 요일 참고 코스 복귀 지난주 당일 코스 주말 차 관광지 사람 생각 최소한 대둔산 케이블카 주말 사람 코스 추천 계획 선택 한국 전통문화 보존 곳 한옥마을 다양 문화유산 팀조 뮤 곳 맛집 서울 지방 변호 사회 소속 지식 법률 상담 진행 김선용 변호사 인 스타 그램 검색 한옥마을 당일치기 질문 여수 제주도 맛집 전 주달 봉 달 봉 티비 코스 곳 여수 여수 제주 제주도 곳 전문 플 언서 전 주달 봉이 흐노 전망 혼자 사람 맛집 곳 중순 계절 현재 코로나 여행객 사람 예상 맛집 이번 주 토 월 여자 친구 경로 토요일 비 실내 데이트 가능 곳 감사 숙소 한옥 마을 근처 토 한옥마을 구경 후 고등학교 친구 당일치기 고등학교 학년 친구 달 당일 예정 부모 말씀 허락 고등학교 시절 친구 추억 갈만 곳 숙소 한옥마을 게스트 하우스 안녕 가족 한옥마을 이번 기회 전라도 음식 전라도 대표 음식 맛집 월요일 휴무 맛집 국내 전 주달 봉 달 봉 티비 코스 곳 여수 여수 제주 제주도 곳 전문 플 언서 전 주달 봉이 걱정 대부분 오픈 볼거리 이번 주 거리 맛집 주 곳 추천 한옥마을 동물원 한국도로공사 수목원 덕진 공원 난장 한옥 마을 근처 숙박 맛집 버스 택시 곳 추천 대중교통 코스 질문 코스 관련 답변 주로 커플 계획 추천 명소 맛집 포함 맞춤 일정 준비 아래 첨부 일정 확인 코스 일정 추천 부탁 토요일 하루 일정 수정 필요 부분 인근 맛집 의견 부탁 맛집 국내 전 주달 봉 달 봉 티비 코스 곳 여수 여수 제주 갈만 곳 한옥마을 한국 전통 가옥 한옥 보존 곳 전통 음식 공예품 남부 시장 현지인 전통 시장 전라도 예정 곳 추천 체험 구용 ...

# %%
import numpy as np
from PIL import Image
from wordcloud import WordCloud
import matplotlib.pyplot as plt
img = Image.open('data/heart.jpg')
mask = np.array(img)
# 불용어 = {'길'}
wordcloud = WordCloud(
    font_path = 'data/NanumPenScript-Regular.ttf',
    background_color = 'white',
    colormap='Blues',
    collocations=True, # 특정 단어가 자주 같이 나오면 같이 뿌려 ex. 황리단길
    max_words=200,
    scale=2, # 이미지 크기의 비율(파일 저장시)
    mask= mask,
    contour_color='red',
    contour_width=1
).generate(gj_text)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# 생성된 wordcloud 저장
wordcloud.to_file('data/naver_경주.jpg')

# %%
import numpy as np
from PIL import Image
from wordcloud import WordCloud
import matplotlib.pyplot as plt
img = Image.open('data/korea-house-black-fill.png')
mask = np.array(img)
# 불용어 = {'길'}
wordcloud = WordCloud(
    font_path = 'data/NanumPenScript-Regular.ttf',
    background_color = 'white',
    colormap='Blues',
    collocations=True, # 특정 단어가 자주 같이 나오면 같이 뿌려 ex. 황리단길
    max_words=200,
    scale=2, # 이미지 크기의 비율(파일 저장시)
    mask= mask,
    contour_color='red',
    contour_width=1
).generate(gj_text)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# 생성된 wordcloud 저장
wordcloud.to_file('data/naver_전주.jpg')

# %% [markdown]
# # ※ 단어의 빈도수 시각화(nltk.Text)

# %%
df_gj_noun_list = df_nouns.loc[df_nouns['query']=='경주 여행','token'].to_list()
df_jj_noun_list = df_nouns.loc[df_nouns['query']=='전주 여행','token'].to_list()

# %%
import nltk
data_text = nltk.Text(df_gj_noun_list)
plt.figure(figsize=(20,5))
plt.rc('font',family = 'Malgun Gothic')
data_text.plot(20)
plt.show()

# %%
word,counts = zip(*data_text.vocab().most_common(20))
# print(word)
# print(counts)
plt.figure(figsize=(20,5))
plt.plot(word,counts)
plt.xticks(rotation=45)
plt.xlabel('word')
plt.ylabel('count')
plt.title('경주 최빈 단어 빈도')
plt.show()

# %% [markdown]
# # 6. 유사도분석
# ## ※Word3Vec

# %%
df = pd.read_csv('data/naver.csv')
df.sample()
# Out:
#      query  no                           title  \
# 509  경주 여행  10  경주 여행 중 꼭 가봐야 할 맛집 리스트는 무엇인가요?
#
#                                                   link  \
# 509  https://kin.naver.com/qna/detail.naver?d1id=8&...
#
#                                            description  \
# 509   경주 여행 을 계획 중이며 필수 방문 맛집과 핫플레이스에 대해 알고 싶습니다 현지...
#
#                                             total_text
# 509  경주 여행 중 꼭 가봐야 할 맛집 리스트는 무엇인가요?  경주 여행 을 계획 중이며...

# %%
total_text_list = df['total_text'].to_list()
total_text_list[:2]
# Out:
# ['25년10월5,6,7일 전주여행  전주여행 가볼만한 곳 추천부탁드립니다 25년 10월 초 전주여행 아이들과 함께 가기 좋은 시점이에요 추석에는 문 연 곳이 적을 수 있지만 전주 한옥마을이나 전주비빔밥 맛집은 추천해용 차는 밀릴 가능성이 높으니 미리 출발하는 ',
#  'KTX로 떠나는 전주 여행, 주요 관광지 도보 이동...   전주 여행 계획 중이시군요 전주역에서 한옥마을까지는 사실 도보로는 좀 멀어요 약 3km 정도 되고 40분 정도 걸립니다 그래서 대부분 택시나 버스를 이용하시는데 택시는 10분 정도면 도착하고 요금도 7 8천원 정도로 부담 없어요 ']

# %%
from mecab import MeCab
select_pos = ['NNP','NNG']
불용어 = {'여행'}
analyzer = MeCab()
total_noun_list = []
for total_text in total_text_list:
    noun_list = [token for token, tag in analyzer.pos(total_text)
                    if tag in select_pos and token not in 불용어 and len(token)>1]
    total_noun_list.append(noun_list)
print(total_noun_list[:2])
# Out:
# [['전주', '전주', '추천', '부탁', '전주', '아이', '시점', '추석', '전주', '한옥마을', '전주비빔밥', '맛집', '추천', '해용', '가능', '출발'], ['전주', '주요', '관광지', '도보', '이동', '전주', '계획', '주역', '한옥마을', '도보', '정도', '정도', '대부분', '택시', '버스', '이용', '택시', '정도', '도착', '요금', '정도', '부담']]

# %%
from gensim.models import Word2Vec
model = Word2Vec(total_noun_list,window=10,min_count=2,workers=-1,
                 sg=1)  # 소량데이터

# %%
model.wv.most_similar('전주')
# Out:
# [('식사', 0.3595535457134247),
#  ('동선', 0.2897421419620514),
#  ('한정식', 0.275379478931427),
#  ('렌트카', 0.2731468081474304),
#  ('현재', 0.2580290138721466),
#  ('전라도', 0.2295033037662506),
#  ('미술관', 0.22023281455039978),
#  ('답변', 0.21883943676948547),
#  ('한옥마을', 0.21617142856121063),
#  ('허락', 0.2135322391986847)]

# %%
model.wv.most_similar('경주')
# Out:
# [('편리', 0.3641005754470825),
#  ('여름', 0.21867415308952332),
#  ('배차', 0.21632219851016998),
#  ('연령', 0.2159893959760666),
#  ('완산구', 0.21469099819660187),
#  ('기림사', 0.2134207934141159),
#  ('다랭이', 0.20914912223815918),
#  ('봉길', 0.20906010270118713),
#  ('패딩', 0.2070489227771759),
#  ('체계', 0.20607852935791016)]

# %% [markdown]
# ## 연관분석

# %%
print(total_noun_list[:2])
# Out:
# [['전주', '전주', '추천', '부탁', '전주', '아이', '시점', '추석', '전주', '한옥마을', '전주비빔밥', '맛집', '추천', '해용', '가능', '출발'], ['전주', '주요', '관광지', '도보', '이동', '전주', '계획', '주역', '한옥마을', '도보', '정도', '정도', '대부분', '택시', '버스', '이용', '택시', '정도', '도착', '요금', '정도', '부담']]

# %%
# %%time
from apyori import apriori
rules = apriori(total_noun_list, min_support=0.15, min_confidence=0.3, min_lift=1.01)
rules = list(rules)
len(rules)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 35.1 ms
# 125

# %%
import pandas as pd
rules_df = pd.DataFrame(None, columns=['lhs', 'rhs', '지지도','신뢰도', '향상도'])
idx = 0
for row in rules:
    support = row[1]
    ordered_st = row[2]
    for item in ordered_st:
        #print(item)
        lhs = item[0]
        lhs = ','.join([x for x in lhs])
        rhs = item[1]
        rhs = ','.join([x for x in rhs])
        confidence = item[2]
        lift = item[3]
        rules_df.loc[idx] = [lhs, rhs, support, confidence, lift]
        idx += 1
#         print("{:10}=>{:16}\t{}\t{}\t{:.2f}".format(lhs, rhs, support, 
#                                                 round(confidence, 2), 
#                                                 lift))
rules_df = rules_df.sort_values(by=['신뢰도', '향상도'], ascending=False)
rules_df.head(20)
# Out:
#           lhs    rhs    지지도  신뢰도       향상도
# 102     여수,국내     티비  0.150  1.0  6.060606
# 132     국내,주달     티비  0.155  1.0  6.060606
# 138     코스,국내     티비  0.155  1.0  6.060606
# 162     맛집,여수     티비  0.155  1.0  6.060606
# 228     여수,주달     티비  0.155  1.0  6.060606
# 234     여수,코스     티비  0.155  1.0  6.060606
# 307     여수,국내  티비,맛집  0.150  1.0  6.060606
# 312  맛집,국내,여수     티비  0.150  1.0  6.060606
# 377     국내,주달  티비,맛집  0.155  1.0  6.060606
# 382  맛집,국내,주달     티비  0.155  1.0  6.060606
# 391     코스,국내  티비,맛집  0.155  1.0  6.060606
# 396  코스,맛집,국내     티비  0.155  1.0  6.060606
# 431     여수,국내  티비,전주  0.150  1.0  6.060606
# 437  여수,국내,전주     티비  0.150  1.0  6.060606
# 458     여수,국내  티비,주달  0.150  1.0  6.060606
# 464  여수,국내,주달     티비  0.150  1.0  6.060606
# 471     여수,국내  티비,코스  0.150  1.0  6.060606
# 477  코스,여수,국내     티비  0.150  1.0  6.060606
# 500     국내,주달  티비,전주  0.155  1.0  6.060606
# 505  국내,전주,주달     티비  0.155  1.0  6.060606
