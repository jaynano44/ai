# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:90% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.text_cell_render.rendered_html{font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:90% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.text_cell_render.rendered_html{font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# # <span style="color:red">ch09.03_ChatUpstage와 랭체인을 활용한 검증</span>

# %% [markdown]
# # 1. 환경(패키지install 및 환경 변수 load)
# - pip install langchain-upstage

# %%
# %pip install -q langchain-upstage --no-warn-script-location
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # 2. LLM답변생성
# ## 2.1 OpenAI SDK를 사용

# %%
import openai

# %%
from openai import OpenAI # openai==2.90
import os
client = OpenAI(
    api_key=os.getenv("UPSTAGE_API_KEY"),
    base_url="https://api.upstage.ai/v1"
)

# %%
response = client.chat.completions.create(
    model="solar-pro2",
    messages=[
        {"role":"system","content":"너는 친절하게 대답해 주는 비서야"},
        {"role":"user","content":"2020년 월드 시리즈 누가 우승했어?"}
    ],
    temperature=0.5,
    stream=False
)

# %%
print(response.choices[0].message.content)
# Out:
# 2020년 월드 시리즈에서는 **로스앤젤레스 다저스**가 우승했습니다!
#
# 다저스는 탬파베이 레이스를 4승 2패로 꺾고, 32년 만에 통산 28번째 월드시리즈 타이틀을 획득했습니다. 특히 이 해는 코로나19 영향으로 단축 시즌(60경기)으로 진행되었지만, 다저스는 강력한 전력을 바탕으로 압도적인 성적을 기록하며 우승을 차지했습니다.
#
# 주요 활약 선수로는 클레이턴 커쇼, 코리 시거, 머키 베츠 등이 있었습니다. 🏆⚾

# %% [markdown]
# ## 2.2 LangChain 선택
#
# - 발급받은 API KEY를 "UPSTAGE_API_KEY"라고 저장하고 별도의 설정없이 ChatUpstage를 바로 사용

# %%
from langchain_upstage import ChatUpstage
from langchain_core.messages import SystemMessage,HumanMessage
llm = ChatUpstage()
messages = [
    SystemMessage(content = "너는 친절하게 대답해 주는 비서야"),
    HumanMessage(content = "2020년 월드 시리즈 누가 우승했어?")
]
ai_message = llm.invoke(input=messages)
ai_message
# Out:
# AIMessage(content='2020년 월드 시리즈는 로스앤젤레스 다저스가 우승했습니다. 이는 다저스의 7번째 월드 시리즈 우승이었으며, 1988년 이후 32년 만의 우승이었습니다. 시리즈에서 다저스는 탬파베이 레이스를 4승 2패로 꺾었습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 36, 'total_tokens': 106, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': '81b11e74-9cd1-4a91-9725-ee9d928a8079', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b96e3-0b93-7201-881a-324a38a71c94-0', usage_metadata={'input_tokens': 36, 'output_tokens': 70, 'total_tokens': 106, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
ai_message.content
# Out:
# '2020년 월드 시리즈는 로스앤젤레스 다저스가 우승했습니다. 이는 다저스의 7번째 월드 시리즈 우승이었으며, 1988년 이후 32년 만의 우승이었습니다. 시리즈에서 다저스는 탬파베이 레이스를 4승 2패로 꺾었습니다.'
